# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path1 = '/content/drive/My Drive/Colab Notebooks/Asgmt3/Population.csv'
file_path2 = '/content/drive/My Drive/Colab Notebooks/Asgmt3/Metadata_Country.csv'

# %%
import pandas as pd

# Load the population dataset, specifying the encoding
pop_Data = pd.read_csv(file_path1) # or 'cp1252', or other encodings
Country_meta_Data = pd.read_csv(file_path2) # Apply the same encoding for other files if needed

# %%
pop_Data.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2015         2016         2017         2018  \
# ...

# %%
pop_Data.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', 'Unnamed: 68'],
#       dtype='object')

# %%
# Columns to retain
columns_to_keep = ['Country Name', 'Country Code', '2020', '2021', '2022', '2023']

# Create a new dataframe with only the selected columns
pop_Data_subset = pop_Data[columns_to_keep]

# Inspect the subset to ensure it only contains the selected columns
print("Subset of Population Data with selected columns:")
pop_Data_subset.head()
# Out:
# Subset of Population Data with selected columns:
#                   Country Name Country Code         2020         2021  \
# 0                        Aruba          ABW     106585.0     106537.0
# 1  Africa Eastern and Southern          AFE  685112979.0  702977106.0
# 2                  Afghanistan          AFG   38972230.0   40099462.0
# 3   Africa Western and Central          AFW  466189102.0  478185907.0
# 4                       Angola          AGO   33428486.0   34503774.0
#
#           2022         2023
# 0     106445.0     106277.0
# 1  720859132.0  739108306.0
# 2   41128771.0   42239854.0
# 3  490330870.0  502789511.0
# 4   35588987.0   36684202.0

# %%
# Check for missing value in Population subset
print("Population subset dataset checksum:")
print(pop_Data_subset.isnull().sum())
# Out:
# Population subset dataset checksum:
# Country Name    0
# Country Code    0
# 2020            1
# 2021            1
# 2022            1
# 2023            1
# dtype: int64

# %%
print("\nCountry Metadata Cleaned:")
Country_meta_Data.head()
# Out:
# Country Metadata Cleaned:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...
#
#                      TableName  Unnamed: 5
# 0                        Aruba         NaN
# 1  Africa Eastern and Southern         NaN
# 2                  Afghanistan         NaN
# 3   Africa Western and Central         NaN
# ...

# %%
print(Country_meta_Data.isnull().sum())
# Out:
# Country Code      0
# Region           48
# IncomeGroup      49
# SpecialNotes    138
# TableName         0
# Unnamed: 5      265
# dtype: int64

# %%
# Drop unnecessary columns in the metadata country dataset
Country_meta_Data = Country_meta_Data.drop(columns=['TableName', 'Unnamed: 5', 'SpecialNotes'], errors='ignore')

# Fill missing values for 'Region', 'IncomeGroup', and 'SpecialNotes'
Country_meta_Data['Region'] = Country_meta_Data['Region'].fillna('Unknown')
Country_meta_Data['IncomeGroup'] = Country_meta_Data['IncomeGroup'].fillna('Unknown')

# Inspect the cleaned dataset
print("After filling missing values:")
Country_meta_Data.head()
# Out:
# After filling missing values:
#   Country Code                     Region          IncomeGroup
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                    Unknown              Unknown
# 2          AFG                 South Asia           Low income
# 3          AFW                    Unknown              Unknown
# 4          AGO         Sub-Saharan Africa  Lower middle income

# %%
print(Country_meta_Data.isnull().sum())
# Out:
# After filling missing values:
# Country Code    0
# Region          0
# IncomeGroup     0
# dtype: int64

# %%
# Merge datasets on 'Country Code'
merged_population_data = pd.merge( Country_meta_Data, pop_Data_subset, on='Country Code', how='inner')

# Inspect the merged dataset
print("Merged Data:")
merged_population_data.head()
# Out:
# Merged Data:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                    Unknown              Unknown
# 2          AFG                 South Asia           Low income
# 3          AFW                    Unknown              Unknown
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                   Country Name         2020         2021         2022  \
# 0                        Aruba     106585.0     106537.0     106445.0
# 1  Africa Eastern and Southern  685112979.0  702977106.0  720859132.0
# 2                  Afghanistan   38972230.0   40099462.0   41128771.0
# 3   Africa Western and Central  466189102.0  478185907.0  490330870.0
# 4                       Angola   33428486.0   34503774.0   35588987.0
#
#           2023
# 0     106277.0
# 1  739108306.0
# 2   42239854.0
# 3  502789511.0
# 4   36684202.0

# %%
merged_population_data.shape
# Out:
# (265, 8)

# %%
# Save the merged data
merged_population_data.to_csv('merged_population_data.csv', index=False)

# If you're using Google Colab and need to download it:
from google.colab import files
files.download('merged_population_data.csv')
